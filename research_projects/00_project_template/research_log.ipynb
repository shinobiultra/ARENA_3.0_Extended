# %% [markdown]
# # Research Log
#
# Use this notebook for exploratory notes, quick plots, and failed attempts. Do not treat observations here as claims until they are registered in `experiment_registry.csv` and summarized in `paper_skeleton.md`.
